# %%
class node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
        
class BST:
    def newBst(self, root, ele):
        if root==None:
            return node(ele)
        if root.data>ele:
            root.left=self.newBst(root.left,ele)
        else:
            root.right=self.newBst(root.right,ele)
        return root
    
    def ipreorder(self,root):
        if root==None:
            return
        stack=[]
        stack.append(root)
        while stack:
            current=stack.pop()
            print(current.data)
            
            if current.right!=None:
                stack.append(current.right)
            if current.left!=None:
                stack.append(current.left)
                
    def iinorder(self,root):
        current=root
        stack=[]
        
        while True:
            if current != None:
                stack.append(current)
                current=current.left
            elif stack:
                current=stack.pop()
                print(current.data)
                current=current.right
            else:
                break
    def ipostorder(self,root):
   
        stackr=[]
        stackf=[]

        stackr.append(root)
        while stackr:
            
            current=stackr.pop()
            stackf.append(current)

            if current.left!=None:
                stackr.append(current.left)
            if current.right!=None:
                stackr.append(current.right)           
        while stackf:
            current=stackf.pop()
            print(current.data)    
root=None
elements=[10,5,2,7,25,23,20,30]
nBst=BST();
for ele in elements:
    root=nBst.newBst(root,ele);
    
nBst.ipreorder(root)    
print("__________")
nBst.iinorder(root)
print("__________")
nBst.ipostorder(root)
# Out:
# 10
# 5
# 2
# 7
# 25
# 23
# 20
# 30
# __________
# 2
# 5
# 7
# 10
# 20
# 23
# 25
# 30
# __________
# 2
# 7
# 5
# 20
# 23
# 30
# 25
# 10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-96ca37328c63> in <module>
#      71 nBst.iinorder(root)
#      72 print("__________")
# ---> 73 nBst.ipostorder(root)
#      74
#      75
#
# <ipython-input-7-96ca37328c63> in ipostorder(self, root)
#      59                 stackr.append(current.right)
#      60         while stackf != None:
# ---> 61             current=stackf.pop()
#      62             print(current.data)
#      63 root=None
#
# IndexError: pop from empty list
